# %% [markdown]
# # NumPy — New Challenging Activities

# %% [markdown]
# ## Activity 1 — Memory and Data-Type Audit
#
# A company receives sensor measurements as whole numbers from 0 to 60,000.
#
# Create the same array twice:
#
# ```python
# measurements = [1200, 15000, 32000, 58000, 42000, 7000]
# ```
#
# - first as `np.int64`
# - then as `np.uint16`
#
# For both arrays, print:
# - `dtype`
# - `itemsize`
# - `nbytes`
# - `shape`
#
# Then calculate how many bytes are saved by using `uint16` for this small array.
#
# Finally, write one short comment explaining **why `uint16` is suitable here** and one situation where it would be a bad choice.

# %% [markdown]
# ## Activity 2 — Reshape Daily Orders into Weeks
#
# An online shop records the number of orders for 28 consecutive days:
#
# ```python
# orders = np.array([
#     42, 38, 45, 51, 63, 70, 58,
#     40, 44, 47, 55, 66, 72, 61,
#     39, 41, 49, 60, 68, 75, 64,
#     43, 46, 52, 62, 71, 79, 67
# ])
# ```
#
# Reshape the data into a `4 x 7` array where each row represents one week.
#
# Then:
# - print the new shape
# - extract Week 3
# - extract all Monday values (first column)
# - calculate the average number of orders for each week using `axis`
# - identify which week has the highest average
#
# Use NumPy operations rather than manually calculating each week.

# %% [markdown]
# ## Activity 3 — Views vs Copies: Protect the Original Price List
#
# A retailer has this price array:
#
# ```python
# prices = np.array([50., 80., 120., 60., 200., 150.])
# ```
#
# The marketing team wants to experiment with a 20% discount on the middle four products.
#
# 1. Create a slice containing the middle four prices **without** `.copy()`.
# 2. Reduce the first value of that slice by 20%.
# 3. Print the original `prices` array and observe what happened.
# 4. Reset the original data.
# 5. Repeat the experiment using `.copy()` so that the original prices are protected.
#
# At the end, write one sentence explaining why this difference matters in data analysis.

# %% [markdown]
# ## Activity 4 — Vectorized Pricing Scenario
#
# A company sells five products with these base prices:
#
# ```python
# prices = np.array([25., 40., 75., 120., 200.])
# ```
#
# Without using a Python loop, calculate:
# - prices after a 12% discount
# - prices after adding 19% tax to the discounted prices
# - the difference between final prices and original prices
# - the percentage change from original to final prices
#
# Then use `np.round(..., 2)` to display final prices with two decimals.
#
# **Business question:** Did the 19% tax completely cancel the 12% discount? Use your calculated results to answer.

# %% [markdown]
# ## Activity 5 — Branch-by-Product Sales Analysis with `axis`
#
# The rows below represent four store branches and the columns represent three products:
#
# ```python
# sales = np.array([
#     [120, 80, 150],
#     [100, 95, 130],
#     [140, 70, 160],
#     [90, 110, 120]
# ])
# ```
#
# Calculate:
# - total sales for each branch
# - average sales for each product across branches
# - the branch with the highest total
# - the product column with the highest average
# - whether **every branch** sold at least 300 units in total
# - whether **any product** has an average above 140
#
# Do not use Python loops for these calculations.

# %% [markdown]
# ## Activity 6 — Broadcasting Regional Price Adjustments
#
# A company has product prices in three regions. Each row is a region and each column is a product:
#
# ```python
# base_prices = np.array([
#     [100., 80., 60., 50.],
#     [100., 80., 60., 50.],
#     [100., 80., 60., 50.]
# ])
# ```
#
# Regional adjustment rates are:
#
# ```python
# rates = np.array([0.05, 0.10, -0.03])
# ```
#
# Meaning:
# - Region 1: +5%
# - Region 2: +10%
# - Region 3: -3%
#
# Use broadcasting to create a new price matrix **without a loop**.
#
# Hint: decide whether `rates` needs to be reshaped to `(3, 1)`.
#
# Then print:
# - adjusted prices
# - average adjusted price for each region
# - which region has the highest average price.

# %% [markdown]
# ## Activity 7 — Inventory Risk Mask
#
# A warehouse records inventory for eight products:
#
# ```python
# stock = np.array([12, 4, 0, 25, 7, 3, 18, 2])
# monthly_demand = np.array([10, 8, 5, 12, 9, 6, 14, 4])
# ```
#
# Create Boolean masks to identify:
# - products with stock below 5
# - products where stock is lower than expected monthly demand
# - products that satisfy **both** conditions
# - products with zero stock **or** demand greater than 10
#
# Then:
# - print the indices of the products in the highest-risk group
# - count how many products are high risk
# - print the corresponding stock values
#
# Use NumPy masks and logical operators (`&`, `|`).

# %% [markdown]
# ## Activity 8 — Customer Segmentation with Boolean Logic
#
# A company has customer spending and visit counts:
#
# ```python
# spend = np.array([220, 80, 450, 130, 600, 95, 310, 500])
# visits = np.array([5, 2, 8, 6, 10, 1, 4, 7])
# ```
#
# Define:
# - **VIP**: spend >= 400 AND visits >= 7
# - **Potential VIP**: spend >= 300 OR visits >= 6, but not already VIP
# - **Low engagement**: spend < 150 AND visits < 4
#
# Create the masks and print the customer indices in each segment.
#
# Then calculate the average spend of VIP customers.
#
# Do this without writing a loop over customers.

# %% [markdown]
# ## Activity 9 — Fancy Indexing: Audit Specific Transactions
#
# A transaction matrix contains four stores (rows) and five days (columns):
#
# ```python
# transactions = np.array([
#     [21, 25, 19, 30, 28],
#     [18, 22, 24, 20, 27],
#     [35, 31, 29, 33, 36],
#     [16, 19, 21, 18, 23]
# ])
# ```
#
# An auditor wants exactly these cells:
# - Store 1, Day 2
# - Store 3, Day 5
# - Store 4, Day 1
# - Store 2, Day 4
#
# Use **fancy indexing** with row and column index arrays to extract all four values in one operation.
#
# Then:
# - calculate their average
# - change only these selected cells to `-1` in a **copy** of the matrix to mark them as reviewed
# - print both the original and reviewed matrices to prove the original is unchanged.

# %% [markdown]
# ## Activity 10 — Ranking Products with `argsort`
#
# A company measures quarterly profit for six products:
#
# ```python
# products = np.array(["A", "B", "C", "D", "E", "F"])
# profit = np.array([12000, 5000, 18000, -2000, 9000, 15000])
# ```
#
# Use `np.argsort()` to:
# - rank products from lowest to highest profit
# - rank products from highest to lowest profit
# - print the top three product names and their profits
# - print the bottom two product names
#
# Important: do not manually type the product order after looking at the numbers. The order must come from the indices returned by NumPy.

# %% [markdown]
# ## Activity 11 — Combine Revenue and Cost Data
#
# Two departments send monthly data separately:
#
# ```python
# revenue = np.array([
#     [12000, 15000, 14000],
#     [18000, 17000, 21000]
# ])
#
# cost = np.array([
#     [9000, 10000, 9500],
#     [13000, 12500, 15000]
# ])
# ```
#
# Use `np.dstack()` to create one 3D array with shape `(2, 3, 2)`. In the last dimension:
# - index `0` contains revenue
# - index `1` contains cost
#
# Print the shape and use indexing to prove which layer is revenue and which is cost.
#
# Then calculate a profit matrix (`revenue - cost`) and answer:
# - Which department has the larger total profit?
# - In which month is the total profit across both departments highest?
#
# Print the relevant arrays and results.

# %% [markdown]
# ## Activity 12 — E-Commerce Portfolio Analysis: Final Challenge
#
# You are analyzing five products across four regions.
#
# ```python
# units = np.array([
#     [120, 80, 150, 90, 110],
#     [100, 95, 130, 105, 125],
#     [140, 70, 160, 100, 135],
#     [90, 110, 120, 115, 100]
# ])
#
# price = np.array([25., 40., 18., 55., 30.])
# cost = np.array([15., 28., 10., 35., 21.])
# ```
#
# Using NumPy and **no Python loops**, calculate:
#
# 1. Revenue for every region-product combination.
# 2. Profit for every region-product combination.
# 3. Total profit by region.
# 4. Total profit by product.
# 5. The most profitable region.
# 6. The most profitable product.
# 7. A Boolean mask showing where profit is at least 1,500.
# 8. How many region-product combinations reach that threshold.
# 9. The product names ranked from highest to lowest total profit.
#
# Use:
#
# ```python
# product_names = np.array(["P1", "P2", "P3", "P4", "P5"])
# ```
#
# Finally, write **two business observations** based on your output. The observations should not merely repeat the largest number; explain what the result could mean for a manager.
